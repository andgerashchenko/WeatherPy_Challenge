# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
import requests as requests
from config import weather_api__key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api__key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]

            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_current_weather})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longonjo
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | sobolevo
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | dharchula
# Processing Record 6 of Set 1 | leninskoye
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | ufa
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | alofi
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | nelson bay
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | falkoping
# City not found. Skipping...
# Processing Record 23 of Set 1 | luganville
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | ola
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | vardo
# Processing Record 28 of Set 1 | sabang
# Processing Record 29 of Set 1 | egvekinot
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | san javier
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | brae
# Processing Record 36 of Set 1 | kutum
# Processing Record 37 of Set 1 | saint-pierre
# Processing Record 38 of Set 1 | kohlu
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | kruisfontein
# Processing Record 42 of Set 1 | harrismith
# Processing Record 43 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | bozeman
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | waynesville
# Processing Record 2 of Set 2 | eureka
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | cariamanga
# Processing Record 5 of Set 2 | flinders
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | agadez
# Processing Record 10 of Set 2 | dunedin
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | mandera
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | umm kaddadah
# Processing Record 18 of Set 2 | faya
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | taltal
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | cap malheureux
# Processing Record 23 of Set 2 | karabanovo
# Processing Record 24 of Set 2 | umm ruwabah
# City not found. Skipping...
# Processing Record 25 of Set 2 | kampot
# Processing Record 26 of Set 2 | lida
# Processing Record 27 of Set 2 | kashan
# Processing Record 28 of Set 2 | fort nelson
# Processing Record 29 of Set 2 | peterhead
# Processing Record 30 of Set 2 | kajaani
# Processing Record 31 of Set 2 | karaton
# Processing Record 32 of Set 2 | udachnyy
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | nemuro
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | vila franca do campo
# Processing Record 41 of Set 2 | phan thiet
# Processing Record 42 of Set 2 | dawei
# Processing Record 43 of Set 2 | jvari
# Processing Record 44 of Set 2 | matagami
# Processing Record 45 of Set 2 | sulangan
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | omboue
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | marawi
# Processing Record 50 of Set 2 | wamba
# Processing Record 1 of Set 3 | dohar
# Processing Record 2 of Set 3 | northam
# Processing Record 3 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | joutseno
# Processing Record 6 of Set 3 | mogocha
# Processing Record 7 of Set 3 | ketchikan
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | bolshoye selo
# Processing Record 14 of Set 3 | tutoia
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | lavrentiya
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | buchanan
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | husavik
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | belyy yar
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | karlstad
# Processing Record 34 of Set 3 | belawan
# Processing Record 35 of Set 3 | san angelo
# Processing Record 36 of Set 3 | meulaboh
# Processing Record 37 of Set 3 | kalush
# Processing Record 38 of Set 3 | ghogha
# Processing Record 39 of Set 3 | honiara
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | diriomo
# Processing Record 44 of Set 3 | lebowakgomo
# Processing Record 45 of Set 3 | pevek
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | myitkyina
# Processing Record 50 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 4 | inirida
# Processing Record 2 of Set 4 | barcelos
# Processing Record 3 of Set 4 | kargat
# Processing Record 4 of Set 4 | lana
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | corvallis
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | bonfim
# Processing Record 9 of Set 4 | qaanaaq
# Processing Record 10 of Set 4 | saint-georges
# Processing Record 11 of Set 4 | slave lake
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | komsomolskiy
# Processing Record 14 of Set 4 | atar
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | zhigansk
# Processing Record 17 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | lere
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | ust-kulom
# Processing Record 22 of Set 4 | seymchan
# Processing Record 23 of Set 4 | toul
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | currais novos
# Processing Record 27 of Set 4 | serenje
# Processing Record 28 of Set 4 | ladario
# Processing Record 29 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 4 | itambe
# Processing Record 31 of Set 4 | bad wildungen
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | andenes
# Processing Record 34 of Set 4 | kanniyakumari
# Processing Record 35 of Set 4 | cabra
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | silvania
# Processing Record 38 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 39 of Set 4 | kununurra
# Processing Record 40 of Set 4 | wanderlandia
# City not found. Skipping...
# Processing Record 41 of Set 4 | strelka
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | mahon
# Processing Record 45 of Set 4 | muros
# Processing Record 46 of Set 4 | zaozerne
# Processing Record 47 of Set 4 | malesici
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | grahamstown
# Processing Record 50 of Set 4 | praia
# Processing Record 1 of Set 5 | olinda
# Processing Record 2 of Set 5 | tazovskiy
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | xuddur
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | morondava
# Processing Record 7 of Set 5 | east london
# Processing Record 8 of Set 5 | norman wells
# Processing Record 9 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 5 | gamba
# Processing Record 11 of Set 5 | san policarpo
# Processing Record 12 of Set 5 | villa del rosario
# Processing Record 13 of Set 5 | sibu
# Processing Record 14 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | aljezur
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | henderson
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | omsukchan
# Processing Record 23 of Set 5 | katsuura
# Processing Record 24 of Set 5 | madhubani
# Processing Record 25 of Set 5 | marzuq
# Processing Record 26 of Set 5 | pangody
# Processing Record 27 of Set 5 | sola
# Processing Record 28 of Set 5 | trairi
# Processing Record 29 of Set 5 | aksu
# Processing Record 30 of Set 5 | ambalavao
# Processing Record 31 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 5 | pundaguitan
# Processing Record 33 of Set 5 | palmer
# Processing Record 34 of Set 5 | kasama
# Processing Record 35 of Set 5 | muisne
# Processing Record 36 of Set 5 | barrow
# Processing Record 37 of Set 5 | la ronge
# Processing Record 38 of Set 5 | cockburn town
# Processing Record 39 of Set 5 | neveklov
# Processing Record 40 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 5 | oudtshoorn
# Processing Record 42 of Set 5 | birjand
# Processing Record 43 of Set 5 | katobu
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | mar del plata
# Processing Record 46 of Set 5 | rio gallegos
# Processing Record 47 of Set 5 | cape town
# Processing Record 48 of Set 5 | terra santa
# Processing Record 49 of Set 5 | juneau
# Processing Record 50 of Set 5 | neuquen
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | namibe
# Processing Record 5 of Set 6 | kosh-agach
# Processing Record 6 of Set 6 | thompson
# Processing Record 7 of Set 6 | semey
# Processing Record 8 of Set 6 | sydney
# Processing Record 9 of Set 6 | sosnovo-ozerskoye
# Processing Record 10 of Set 6 | kuala lipis
# Processing Record 11 of Set 6 | marsh harbour
# Processing Record 12 of Set 6 | turukhansk
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | presidencia roque saenz pena
# Processing Record 15 of Set 6 | mirabad
# Processing Record 16 of Set 6 | kattivakkam
# Processing Record 17 of Set 6 | saalfeld
# Processing Record 18 of Set 6 | saldanha
# Processing Record 19 of Set 6 | pascagoula
# Processing Record 20 of Set 6 | half moon bay
# Processing Record 21 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 6 | boa vista
# Processing Record 23 of Set 6 | holalkere
# Processing Record 24 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 6 | magomeni
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | vila do maio
# Processing Record 28 of Set 6 | oktyabrskoye
# Processing Record 29 of Set 6 | jati
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | yarada
# Processing Record 32 of Set 6 | harper
# Processing Record 33 of Set 6 | riyadh
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | durango
# Processing Record 36 of Set 6 | puerto carreno
# Processing Record 37 of Set 6 | goure
# Processing Record 38 of Set 6 | superior
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | baft
# Processing Record 41 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 6 | lagos
# Processing Record 43 of Set 6 | sesheke
# Processing Record 44 of Set 6 | colac
# Processing Record 45 of Set 6 | ochamchira
# Processing Record 46 of Set 6 | abu kamal
# Processing Record 47 of Set 6 | bangsund
# Processing Record 48 of Set 6 | muli
# Processing Record 49 of Set 6 | mount isa
# Processing Record 50 of Set 6 | tono
# Processing Record 1 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 7 | lhokseumawe
# Processing Record 3 of Set 7 | erzin
# Processing Record 4 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 7 | furth im wald
# Processing Record 6 of Set 7 | den helder
# Processing Record 7 of Set 7 | coari
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | kahului
# Processing Record 10 of Set 7 | le port
# Processing Record 11 of Set 7 | nizhniy odes
# Processing Record 12 of Set 7 | artyom
# Processing Record 13 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 7 | narsaq
# Processing Record 17 of Set 7 | lebedinyy
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 7 | coihaique
# Processing Record 22 of Set 7 | lufilufi
# Processing Record 23 of Set 7 | hirara
# Processing Record 24 of Set 7 | edirne
# Processing Record 25 of Set 7 | vestmannaeyjar
# Processing Record 26 of Set 7 | north platte
# Processing Record 27 of Set 7 | sovetskiy
# Processing Record 28 of Set 7 | general roca
# Processing Record 29 of Set 7 | iralaya
# Processing Record 30 of Set 7 | shubarshi
# Processing Record 31 of Set 7 | caravelas
# Processing Record 32 of Set 7 | mangrol
# Processing Record 33 of Set 7 | maloy
# Processing Record 34 of Set 7 | ibra
# Processing Record 35 of Set 7 | japura
# Processing Record 36 of Set 7 | okato
# Processing Record 37 of Set 7 | bethel
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | vao
# Processing Record 40 of Set 7 | turtas
# Processing Record 41 of Set 7 | pokosnoye
# Processing Record 42 of Set 7 | shenjiamen
# Processing Record 43 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 7 | si sa ket
# Processing Record 45 of Set 7 | porto novo
# Processing Record 46 of Set 7 | leningradskiy
# Processing Record 47 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 7 | sorland
# Processing Record 49 of Set 7 | wapi pathum
# Processing Record 50 of Set 7 | kichera
# Processing Record 1 of Set 8 | ivybridge
# Processing Record 2 of Set 8 | kjollefjord
# Processing Record 3 of Set 8 | monrovia
# Processing Record 4 of Set 8 | pauini
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | mayor pablo lagerenza
# Processing Record 7 of Set 8 | hovd
# Processing Record 8 of Set 8 | takoradi
# Processing Record 9 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 8 | binika
# Processing Record 11 of Set 8 | mufulira
# Processing Record 12 of Set 8 | karratha
# Processing Record 13 of Set 8 | amol
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | abalak
# Processing Record 16 of Set 8 | lata
# Processing Record 17 of Set 8 | urumqi
# Processing Record 18 of Set 8 | san-pedro
# Processing Record 19 of Set 8 | aguilas
# Processing Record 20 of Set 8 | parana
# Processing Record 21 of Set 8 | nanga eboko
# Processing Record 22 of Set 8 | santa cruz
# Processing Record 23 of Set 8 | mao
# Processing Record 24 of Set 8 | jumla
# Processing Record 25 of Set 8 | jalu
# Processing Record 26 of Set 8 | skoghall
# Processing Record 27 of Set 8 | pita
# Processing Record 28 of Set 8 | agogo
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | pemberton
# Processing Record 31 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 32 of Set 8 | maceio
# Processing Record 33 of Set 8 | ergani
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | port hedland
# Processing Record 36 of Set 8 | bela vista
# Processing Record 37 of Set 8 | rongcheng
# Processing Record 38 of Set 8 | shimoda
# Processing Record 39 of Set 8 | sao filipe
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | puerto princesa
# Processing Record 42 of Set 8 | miraflores
# Processing Record 43 of Set 8 | tomatlan
# Processing Record 44 of Set 8 | bichura
# Processing Record 45 of Set 8 | ebolowa
# Processing Record 46 of Set 8 | lompoc
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | korhogo
# Processing Record 49 of Set 8 | rohnert park
# Processing Record 50 of Set 8 | sur
# Processing Record 1 of Set 9 | avarua
# Processing Record 2 of Set 9 | ekhabi
# Processing Record 3 of Set 9 | aspros
# Processing Record 4 of Set 9 | fukue
# Processing Record 5 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 9 | werda
# Processing Record 7 of Set 9 | torbay
# Processing Record 8 of Set 9 | marabba
# Processing Record 9 of Set 9 | port hardy
# Processing Record 10 of Set 9 | san andres
# Processing Record 11 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 9 | kargasok
# Processing Record 13 of Set 9 | lamu
# Processing Record 14 of Set 9 | pochutla
# Processing Record 15 of Set 9 | rocha
# Processing Record 16 of Set 9 | abu samrah
# Processing Record 17 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 18 of Set 9 | floro
# Processing Record 19 of Set 9 | kloulklubed
# Processing Record 20 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 9 | terney
# Processing Record 22 of Set 9 | mayo
# Processing Record 23 of Set 9 | secunda
# Processing Record 24 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 9 | bubaque
# Processing Record 26 of Set 9 | novyy urgal
# Processing Record 27 of Set 9 | san carlos de bariloche
# Processing Record 28 of Set 9 | lagoa
# Processing Record 29 of Set 9 | belaya gora
# Processing Record 30 of Set 9 | cambara
# Processing Record 31 of Set 9 | igrim
# Processing Record 32 of Set 9 | ilva mica
# Processing Record 33 of Set 9 | wanaka
# Processing Record 34 of Set 9 | praya
# Processing Record 35 of Set 9 | walvis bay
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 9 | hailey
# Processing Record 40 of Set 9 | the valley
# Processing Record 41 of Set 9 | tancheng
# Processing Record 42 of Set 9 | sendafa
# Processing Record 43 of Set 9 | hohhot
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | sechura
# Processing Record 46 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | hommelvik
# Processing Record 49 of Set 9 | gravdal
# Processing Record 50 of Set 9 | norfolk
# Processing Record 1 of Set 10 | ust-kuyga
# Processing Record 2 of Set 10 | makubetsu
# Processing Record 3 of Set 10 | hay river
# Processing Record 4 of Set 10 | tura
# Processing Record 5 of Set 10 | bilibino
# Processing Record 6 of Set 10 | santa rosalia
# Processing Record 7 of Set 10 | iskele
# Processing Record 8 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 9 of Set 10 | langsa
# Processing Record 10 of Set 10 | dergachi
# Processing Record 11 of Set 10 | tavistock
# Processing Record 12 of Set 10 | vibo valentia
# Processing Record 13 of Set 10 | christchurch
# Processing Record 14 of Set 10 | bangarapet
# Processing Record 15 of Set 10 | jardim
# Processing Record 16 of Set 10 | rosarito
# Processing Record 17 of Set 10 | sembe
# Processing Record 18 of Set 10 | berlevag
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | aykhal
# Processing Record 21 of Set 10 | charters towers
# Processing Record 22 of Set 10 | ust-nera
# Processing Record 23 of Set 10 | dutlwe
# Processing Record 24 of Set 10 | elat
# Processing Record 25 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | kaka
# Processing Record 27 of Set 10 | bembereke
# Processing Record 28 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 29 of Set 10 | laureles
# Processing Record 30 of Set 10 | kendari
# Processing Record 31 of Set 10 | luanda
# Processing Record 32 of Set 10 | paka
# Processing Record 33 of Set 10 | tamiahua
# Processing Record 34 of Set 10 | kontagora
# Processing Record 35 of Set 10 | mbini
# Processing Record 36 of Set 10 | labuan
# Processing Record 37 of Set 10 | sokoni
# Processing Record 38 of Set 10 | west wendover
# Processing Record 39 of Set 10 | tokur
# Processing Record 40 of Set 10 | malatya
# Processing Record 41 of Set 10 | kirakira
# Processing Record 42 of Set 10 | bireun
# Processing Record 43 of Set 10 | teahupoo
# Processing Record 44 of Set 10 | naze
# Processing Record 45 of Set 10 | campbell river
# Processing Record 46 of Set 10 | tateyama
# Processing Record 47 of Set 10 | vizianagaram
# Processing Record 48 of Set 10 | matadi
# Processing Record 49 of Set 10 | pedernales
# Processing Record 50 of Set 10 | san pedro de ycuamandiyu
# Processing Record 1 of Set 11 | high prairie
# Processing Record 2 of Set 11 | gigmoto
# Processing Record 3 of Set 11 | brownsville
# Processing Record 4 of Set 11 | havre-saint-pierre
# Processing Record 5 of Set 11 | tumkur
# Processing Record 6 of Set 11 | rovnoye
# Processing Record 7 of Set 11 | la rioja
# Processing Record 8 of Set 11 | praia da vitoria
# Processing Record 9 of Set 11 | hofn
# Processing Record 10 of Set 11 | mokrous
# Processing Record 11 of Set 11 | coahuayana
# Processing Record 12 of Set 11 | waounde
# Processing Record 13 of Set 11 | samarkand
# Processing Record 14 of Set 11 | ulladulla
# Processing Record 15 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 11 | pathankot
# Processing Record 17 of Set 11 | whyalla
# Processing Record 18 of Set 11 | goundam
# Processing Record 19 of Set 11 | padang
# Processing Record 20 of Set 11 | la macarena
# Processing Record 21 of Set 11 | savinka
# Processing Record 22 of Set 11 | beni
# Processing Record 23 of Set 11 | nalut
# Processing Record 24 of Set 11 | nuevo progreso
# Processing Record 25 of Set 11 | zhangjiakou
# Processing Record 26 of Set 11 | falmouth
# Processing Record 27 of Set 11 | nova aurora
# Processing Record 28 of Set 11 | goderich
# Processing Record 29 of Set 11 | payyannur
# Processing Record 30 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 11 | namasuba
# Processing Record 32 of Set 11 | mareeba
# Processing Record 33 of Set 11 | pilar
# Processing Record 34 of Set 11 | kingaroy
# Processing Record 35 of Set 11 | gasa
# Processing Record 36 of Set 11 | hailar
# Processing Record 37 of Set 11 | whitianga
# Processing Record 38 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 11 | stange
# Processing Record 40 of Set 11 | biak
# Processing Record 41 of Set 11 | shitanjing
# Processing Record 42 of Set 11 | miri
# Processing Record 43 of Set 11 | palmeiras de goias
# Processing Record 44 of Set 11 | pacifica
# Processing Record 45 of Set 11 | henties bay
# Processing Record 46 of Set 11 | nokaneng
# Processing Record 47 of Set 11 | butajira
# Processing Record 48 of Set 11 | soure
# Processing Record 49 of Set 11 | lexington
# Processing Record 50 of Set 11 | yulara
# Processing Record 1 of Set 12 | xichang
# Processing Record 2 of Set 12 | berbera
# Processing Record 3 of Set 12 | marivan
# Processing Record 4 of Set 12 | mehamn
# Processing Record 5 of Set 12 | bath
# Processing Record 6 of Set 12 | san jose
# Processing Record 7 of Set 12 | sorong
# Processing Record 8 of Set 12 | vallenar
# Processing Record 9 of Set 12 | ponta delgada
# Processing Record 10 of Set 12 | mahibadhoo
# Processing Record 11 of Set 12 | hobyo
# Processing Record 12 of Set 12 | berdyuzhye
# City not found. Skipping...
# Processing Record 13 of Set 12 | klaksvik
# Processing Record 14 of Set 12 | nortelandia
# Processing Record 15 of Set 12 | zyryanka
# Processing Record 16 of Set 12 | talara
# Processing Record 17 of Set 12 | san cristobal
# Processing Record 18 of Set 12 | itupiranga
# Processing Record 19 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 12 | kholodnyy
# Processing Record 21 of Set 12 | samarai
# Processing Record 22 of Set 12 | loandjili
# Processing Record 23 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 12 | sisimiut
# Processing Record 25 of Set 12 | bereda
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | newport
# Processing Record 28 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 29 of Set 12 | riberalta
# Processing Record 30 of Set 12 | kuhdasht
# Processing Record 31 of Set 12 | paita
# Processing Record 32 of Set 12 | clarksburg
# Processing Record 33 of Set 12 | krasnoselkup
# Processing Record 34 of Set 12 | tahe
# Processing Record 35 of Set 12 | luwuk
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | dzheyrakh
# Processing Record 38 of Set 12 | mannarakkat
# Processing Record 39 of Set 12 | panaba
# Processing Record 40 of Set 12 | malinovoye ozero
# Processing Record 41 of Set 12 | guangyuan
# Processing Record 42 of Set 12 | thinadhoo
# Processing Record 43 of Set 12 | tarko-sale
# Processing Record 44 of Set 12 | porvoo
# Processing Record 45 of Set 12 | vylkove
# Processing Record 46 of Set 12 | san carlos
# Processing Record 47 of Set 12 | constitucion
# Processing Record 48 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 49 of Set 12 | houston
# Processing Record 50 of Set 12 | senador guiomard
# Processing Record 1 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 13 | wad madani
# Processing Record 3 of Set 13 | pailon
# Processing Record 4 of Set 13 | beyneu
# Processing Record 5 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 6 of Set 13 | saint-paul
# Processing Record 7 of Set 13 | lasa
# Processing Record 8 of Set 13 | warrnambool
# Processing Record 9 of Set 13 | la sarre
# Processing Record 10 of Set 13 | komyshnya
# Processing Record 11 of Set 13 | taoudenni
# Processing Record 12 of Set 13 | catalao
# Processing Record 13 of Set 13 | antofagasta
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | mozarlandia
# Processing Record 16 of Set 13 | scarborough
# Processing Record 17 of Set 13 | monte cristi
# City not found. Skipping...
# Processing Record 18 of Set 13 | melaka
# Processing Record 19 of Set 13 | auki
# Processing Record 20 of Set 13 | hambantota
# Processing Record 21 of Set 13 | mnogovershinnyy
# Processing Record 22 of Set 13 | saurimo
# Processing Record 23 of Set 13 | broome
# Processing Record 24 of Set 13 | narayangarh
# Processing Record 25 of Set 13 | nampula
# Processing Record 26 of Set 13 | axim
# Processing Record 27 of Set 13 | kudahuvadhoo
# Processing Record 28 of Set 13 | casino
# Processing Record 29 of Set 13 | mercedes
# Processing Record 30 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 31 of Set 13 | qingdao
# Processing Record 32 of Set 13 | plettenberg bay
# Processing Record 33 of Set 13 | oum hadjer
# Processing Record 34 of Set 13 | adrar
# Processing Record 35 of Set 13 | lisakovsk
# Processing Record 36 of Set 13 | isangel
# Processing Record 37 of Set 13 | chapais
# Processing Record 38 of Set 13 | grindavik
# Processing Record 39 of Set 13 | ratnagiri
# Processing Record 40 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 41 of Set 13 | el bagre
# Processing Record 42 of Set 13 | grand gaube
# Processing Record 43 of Set 13 | el tigre
# Processing Record 44 of Set 13 | san borja
# Processing Record 45 of Set 13 | sal rei
# Processing Record 46 of Set 13 | humberto de campos
# Processing Record 47 of Set 13 | mazatlan
# Processing Record 48 of Set 13 | bilma
# Processing Record 49 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 13 | sao geraldo do araguaia
# Processing Record 1 of Set 14 | alice springs
# Processing Record 2 of Set 14 | kilindoni
# Processing Record 3 of Set 14 | pak phanang
# Processing Record 4 of Set 14 | abu dhabi
# Processing Record 5 of Set 14 | sungaipenuh
# Processing Record 6 of Set 14 | san quintin
# Processing Record 7 of Set 14 | hazro
# Processing Record 8 of Set 14 | port blair
# Processing Record 9 of Set 14 | west bend
# Processing Record 10 of Set 14 | degollado
# Processing Record 11 of Set 14 | mumford
# Processing Record 12 of Set 14 | richards bay
# Processing Record 13 of Set 14 | hvolsvollur
# Processing Record 14 of Set 14 | ugoofaaru
# Processing Record 15 of Set 14 | meilu
# City not found. Skipping...
# Processing Record 16 of Set 14 | poso
# Processing Record 17 of Set 14 | astana
# Processing Record 18 of Set 14 | pagudpud
# Processing Record 19 of Set 14 | aracaju
# Processing Record 20 of Set 14 | port lincoln
# Processing Record 21 of Set 14 | mocoa
# Processing Record 22 of Set 14 | tres arroyos
# Processing Record 23 of Set 14 | maksatikha
# Processing Record 24 of Set 14 | asgabat
# Processing Record 25 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 26 of Set 14 | lokosovo
# Processing Record 27 of Set 14 | gundlupet
# Processing Record 28 of Set 14 | gimli
# Processing Record 29 of Set 14 | vostok
# Processing Record 30 of Set 14 | cap-aux-meules
# Processing Record 31 of Set 14 | myrtle beach
# Processing Record 32 of Set 14 | avera
# Processing Record 33 of Set 14 | dauriya
# Processing Record 34 of Set 14 | bagdarin
# Processing Record 35 of Set 14 | shache
# Processing Record 36 of Set 14 | pionerskiy
# Processing Record 37 of Set 14 | alyangula
# Processing Record 38 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 39 of Set 14 | white rock
# Processing Record 40 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 14 | veletma
# City not found. Skipping...
# Processing Record 42 of Set 14 | kalmunai
# Processing Record 43 of Set 14 | laguna
# Processing Record 44 of Set 14 | korla
# Processing Record 45 of Set 14 | otaki
# Processing Record 46 of Set 14 | seguela
# Processing Record 47 of Set 14 | port hawkesbury
# Processing Record 48 of Set 14 | potanino
# Processing Record 49 of Set 14 | alta floresta
# Processing Record 50 of Set 14 | kalga
# Processing Record 1 of Set 15 | pachino
# Processing Record 2 of Set 15 | port-gentil
# Processing Record 3 of Set 15 | duvan
# Processing Record 4 of Set 15 | imaculada
# Processing Record 5 of Set 15 | fevik
# Processing Record 6 of Set 15 | comoapan
# Processing Record 7 of Set 15 | salamiyah
# Processing Record 8 of Set 15 | vestmanna
# Processing Record 9 of Set 15 | knysna
# Processing Record 10 of Set 15 | zhezkazgan
# Processing Record 11 of Set 15 | moriyama
# Processing Record 12 of Set 15 | upata
# Processing Record 13 of Set 15 | staraya mayna
# Processing Record 14 of Set 15 | berezyne
# Processing Record 15 of Set 15 | goldap
# Processing Record 16 of Set 15 | malanje
# Processing Record 17 of Set 15 | banda aceh
# Processing Record 18 of Set 15 | dolores
# Processing Record 19 of Set 15 | key west
# Processing Record 20 of Set 15 | borujan
# City not found. Skipping...
# Processing Record 21 of Set 15 | muscat
# Processing Record 22 of Set 15 | shelburne
# Processing Record 23 of Set 15 | ostrovnoy
# Processing Record 24 of Set 15 | presidente epitacio
# Processing Record 25 of Set 15 | razole
# Processing Record 26 of Set 15 | talnakh
# Processing Record 27 of Set 15 | wangkui
# Processing Record 28 of Set 15 | pacific grove
# Processing Record 29 of Set 15 | krasne
# Processing Record 30 of Set 15 | martapura
# Processing Record 31 of Set 15 | terrace
# Processing Record 32 of Set 15 | konanur
# Processing Record 33 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 15 | poum
# Processing Record 35 of Set 15 | riviere-au-renard
# Processing Record 36 of Set 15 | flagstaff
# Processing Record 37 of Set 15 | aitape
# Processing Record 38 of Set 15 | amapa
# Processing Record 39 of Set 15 | enumclaw
# Processing Record 40 of Set 15 | ishigaki
# Processing Record 41 of Set 15 | san luis
# Processing Record 42 of Set 15 | chicama
# Processing Record 43 of Set 15 | monroe
# Processing Record 44 of Set 15 | koppang
# Processing Record 45 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 46 of Set 15 | pangai
# Processing Record 47 of Set 15 | moyale
# Processing Record 48 of Set 15 | outjo
# Processing Record 49 of Set 15 | sept-iles
# Processing Record 50 of Set 15 | kasempa
# Processing Record 1 of Set 16 | bassila
# Processing Record 2 of Set 16 | standerton
# Processing Record 3 of Set 16 | addi ugri
# City not found. Skipping...
# Processing Record 4 of Set 16 | poya
# Processing Record 5 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 16 | melfi
# Processing Record 7 of Set 16 | jinchang
# Processing Record 8 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 16 | mogadouro
# Processing Record 10 of Set 16 | amahai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 678       Outjo      NA -20.1167   16.1500     59.94        42           0
# 679   Sept-Iles      CA  50.2001  -66.3821     51.26        38         100
# 680     Kasempa      ZM -13.4584   25.8338     57.36        57           3
# 681     Bassila      BJ   9.0081    1.6654     77.59        73          34
# 682  Standerton      ZA -26.9337   29.2415     46.62        40           2
# 683        Poya      NC -21.3500  165.1500     71.44        66          50
# 684       Melfi      IT  40.9965   15.6514     62.40        61          17
# 685    Jinchang      CN  38.4953  102.1739     51.44        24           3
# 686   Mogadouro      PT  41.3403   -6.7119     47.79        66          12
# 687      Amahai      ID  -3.3333  128.9167     77.97        90         100
#
#      Wind Speed Current Description
# 678        9.17           clear sky
# 679       10.00     overcast clouds
# 680        7.72           clear sky
# 681        2.48          light rain
# 682        1.88           clear sky
# 683        8.14    scattered clouds
# 684        3.60          few clouds
# 685        4.90           clear sky
# 686        6.49          few clouds
# 687        6.53          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
